# %%
import sqlite3
import pandas as pd

# %%
# Connect to database
conn = sqlite3.connect("../sql/manufacturing.db")

# %%
# List tables
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("Tables:", tables)
# Out:
# Tables: [('validated_data',)]

# %%
# Read and display the main table
df = pd.read_sql("SELECT * FROM validated_data", conn)
df
# Out:
#    event_id serial_number    process_step  measured_value  \
# 0         1         A1001  Autoclave_Cure          182.50
# 1         2         A1001  Autoclave_Cure          195.20
# 2         3         A1002     CNC_Milling            0.42
#
#             event_time work_order_id part_number  lower_limit  upper_limit  \
# 0  2026-01-01 10:05:00        WO-001      P-9001       175.00       190.00
# 1  2026-01-01 10:15:00        WO-001      P-9001       175.00       190.00
# 2  2026-01-01 11:20:00        WO-002      P-9002         0.35         0.45
#
#    out_of_spec  consecutive_failures
# 0            0                     0
# 1            1                     1
# 2            0                     0

# %%
conn.close()
